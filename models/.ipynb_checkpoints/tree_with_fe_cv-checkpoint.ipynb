# %%
import pandas as pd 
import numpy 
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold,RandomizedSearchCV 
from sklearn.metrics import accuracy_score, recall_score,make_scorer,confusion_matrix, classification_report
import os
from pathlib import Path
from scipy.stats import randint
import seaborn as sns
import matplotlib.pyplot as plt

# %%
PROJECT_ROOT = Path.cwd().parent
os.chdir(PROJECT_ROOT)

# %%
X = pd.read_csv("data/fe/X_train_fe.csv")
y = pd.read_csv("data/fe/y_train.csv").squeeze()

# %%
cat_cols = [c for c in ['Sex','Embarked','Title'] if c in X.columns]
X = pd.get_dummies(
    X,
    columns = cat_cols,
    drop_first =True
)

# %%
X.head()
# Out:
#    Pclass   Age  SibSp  Parch      Fare  FamilySize  IsAlone  Sex_male  \
# 0       3  28.5      0      0   56.4958           1        1      True
# 1       2  28.5      0      0    0.0000           1        1      True
# 2       1  28.5      0      0  221.7792           1        1      True
# 3       3  18.0      0      1    9.3500           2        0     False
# 4       2  31.0      1      1   26.2500           3        0     False
#
#    Embarked_Missing  Embarked_Q  Embarked_S  Title_Miss  Title_Mr  Title_Mrs  \
# 0             False       False        True       False      True      False
# 1             False       False        True       False      True      False
# 2             False       False        True       False      True      False
# 3             False       False        True       False     False       True
# 4             False       False        True       False     False       True
#
#    Title_Rare
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False

# %%
skf = StratifiedKFold (
    n_splits = 5,
    shuffle = True,
    random_state = 42
)

# %%
param_dist = {
    "n_estimators": randint(200, 1200),         
    "max_depth": randint(2, 30),
    "min_samples_split": randint(2, 40),
    "min_samples_leaf": randint(1, 25),
    "max_features": ["sqrt", "log2", None],      
    "bootstrap": [True, False],
    "criterion": ["gini", "entropy", "log_loss"],
    "class_weight": [None, "balanced"]
}

# %%
scorer = make_scorer(recall_score)

# %%
search = RandomizedSearchCV(
    estimator=RandomForestClassifier(
        random_state=42,
        n_jobs=-1
    ),
    param_distributions=param_dist,
    n_iter=50,
    scoring=scorer,
    cv=skf,
    n_jobs=-1,
    random_state=42,
    verbose=1
)
search.fit(X,y)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#                    estimator=RandomForestClassifier(n_jobs=-1, random_state=42),
#                    n_iter=50, n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'class_weight': [None, 'balanced'],
#                                         'criterion': ['gini', 'entropy',
#                                                       'log_loss'],
#                                         'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen objec...
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001F8E5DB6600>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001F8E5DB52B0>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000001F8E5BDED80>},
#                    random_state=42,
#                    scoring=make_scorer(recall_score, response_method='predict'),
#                    verbose=1)

# %%
print('Лучшая оценка',search.best_score_)
# Out:
# Лучшая оценка 0.7764309764309765

# %%
search.best_params_
# Out:
# {'bootstrap': False,
#  'class_weight': 'balanced',
#  'criterion': 'gini',
#  'max_depth': 21,
#  'max_features': 'log2',
#  'min_samples_leaf': 6,
#  'min_samples_split': 23,
#  'n_estimators': 1106}

# %% [markdown]
# ## Обучение модели на лучших гиперпараметрах

# %%
X_test = pd.read_csv("data/fe/X_test_fe.csv")
y_test = pd.read_csv("data/fe/y_test.csv").squeeze()

# %%
X_test = pd.get_dummies(
    X_test,
    columns = cat_cols,
    drop_first =True
)
X, X_test = X.align(X_test, axis=1, fill_value=0)

# %%
final_tree = RandomForestClassifier(
    **search.best_params_,
    random_state=42
)
final_tree.fit(X, y)
# Out:
# RandomForestClassifier(bootstrap=False, class_weight='balanced', max_depth=21,
#                        max_features='log2', min_samples_leaf=6,
#                        min_samples_split=23, n_estimators=1106,
#                        random_state=42)

# %%
y_pred = final_tree.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.8100558659217877

# %%
recall_score(y_test, y_pred)
# Out:
# 0.8115942028985508

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[89, 21],
#        [13, 56]])

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.81      0.84       110
#            1       0.73      0.81      0.77        69
#
#     accuracy                           0.81       179
#    macro avg       0.80      0.81      0.80       179
# weighted avg       0.82      0.81      0.81       179

# %%
accuracy = accuracy_score(y_test, y_pred)
error_rate = 1 -accuracy
print(f'Точность R^2: {accuracy}')
print(f'Доля ошибочных классификаций: {error_rate}')
# Out:
# Точность R^2: 0.8100558659217877
# Доля ошибочных классификаций: 0.1899441340782123

# %%
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, cmap=sns.cubehelix_palette(as_cmap=True))
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
# Out:
# Text(50.722222222222214, 0.5, 'True Label')
